# %%
import requests
import zipfile
from pathlib import Path
import pandas as pd

# English bulk download URL
zip_url = "https://cdfd.iati.opendataservices.coop/output/web/xlsx/cdfd-xlsx-files-en.zip"

# Save folder (change if you want)
out_dir = Path("/content/drive/MyDrive/INFO 430 Group Project/countrydata_english")
out_dir.mkdir(parents=True, exist_ok=True)

zip_path = out_dir / "cdfd-en.zip"

# 1. Download the ZIP file
if out_dir.exists() and zip_path.exists():
    print("ZIP file and folder already exist — skipping download/extraction.")
else:
    # Create folder if missing
    out_dir.mkdir(parents=True, exist_ok=True)

    # 1. Download the ZIP file
    print("Downloading English country data ZIP...")

    with requests.get(zip_url, stream=True, timeout=300) as r:
        r.raise_for_status()
        with open(zip_path, "wb") as f:
            for chunk in r.iter_content(chunk_size=1024 * 1024):
                if chunk:
                    f.write(chunk)

    print("Download complete:", zip_path)

    # 2. Extract all Excel files
    print("Extracting files...")

    with zipfile.ZipFile(zip_path, "r") as z:
        z.extractall(out_dir)

    print("Done!")
    print("All English country Excel files saved in:", out_dir.resolve())
